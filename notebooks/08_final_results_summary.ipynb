# %%
import pandas as pd

task1 = pd.read_csv("../results/metrics/task1_model_comparison.csv")
task2 = pd.read_csv("../results/metrics/task2_vietnam_metrics.csv")
task3 = pd.read_csv("../results/metrics/task3_signal_metrics.csv")
task4 = pd.read_csv("../results/metrics/task4_summary_metrics.csv")

# %%
task1
task2
task3
task4
# Out:
#                          Metric Value
# 0      Best profitability stock   VCB
# 1             Lowest risk stock   VNM
# 2            Highest risk stock   HPG
# 3  Largest portfolio allocation   VNM

# %%
best_models = pd.read_csv(
    "../results/metrics/task1_best_models.csv"
)

best_models
# Out:
#                                 Task Model      RMSE       MAE
# 0     Task 1.1 - Next-day prediction   CNN  0.024287  0.016860
# 1      Task 1.2 - 7th day prediction   CNN  0.096379  0.071221
# 2  Task 1.3 - Next 7 days prediction   CNN  0.057226  0.039113

# %%
portfolio = pd.read_csv(
    "../results/tables/task4_selected_portfolio_table.csv"
)

portfolio
# Out:
#   Ticker  Cumulative_Return_120D  Average_Daily_Return  Volatility  \
# 0    VNM               -0.012181              0.000053    0.015721
# 1    VCB                0.130593              0.001236    0.020213
# 2    FPT               -0.061772             -0.000412    0.017769
#
#    Max_Drawdown  Return_Rank  Risk_Rank  Combined_Score  Inverse_Score  \
# 0     -0.105432          2.0        1.0             1.6       0.625000
# 1     -0.250302          1.0        3.0             1.8       0.555556
# 2     -0.231935          3.0        2.0             2.6       0.384615
#
#    Allocation
# 0    0.399317
# 1    0.354949
# 2    0.245734

# %%
from IPython.display import Image, display

# %%
display(
    Image("../results/figures/task1_rmse_model_comparison.png")
)
